# %%
import sklearn
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Linear

# %%
np.random.seed(2024)

m = 50
X = np.random.rand(m,1)
y = (4 + 3 * X + np.random.randn(m,1)).ravel()

# %%
X.shape, y.shape
# Out:
# ((50, 1), (50,))

# %%
plt.plot(X, y, 'o')
plt.show()

# %%
from sklearn.svm import LinearSVR

svm_reg = LinearSVR(epsilon=1.5, random_state=2024)

svm_reg.fit(X, y)
# Out:
# /home/codespace/.local/lib/python3.10/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# LinearSVR(epsilon=1.5, random_state=2024)

# %%
svm_reg.predict(X[1,:])

# %%
X[:1,:]
# Out:
# array([[0.58801452]])

# %%
X[1,:]
# Out:
# array([0.69910875])

# %% [markdown]
# ## Nonlinear, Kernel

# %%
np.random.seed(2024)

m = 100
X = 2 * np.random.rand(m, 1) - 1
y = (0.2 + 0.1 * X + 0.5 * X**2 + np.random.randn(m, 1)/10).ravel()

plt.plot(X, y, "o")
plt.show()

# %%
from sklearn.svm import SVR

svm_poly_reg = SVR(kernel='poly', degree=2, C=100, epsilon=0.1)

# %%
svm_poly_reg.fit(X, y)
# Out:
# SVR(C=100, degree=2, kernel='poly')

# %%
svm_poly_reg.predict(X[:10, :])
# Out:
# array([0.23646175, 0.29212665, 0.32567943, 0.60006333, 0.30467589,
#        0.48472294, 0.32712501, 0.27410221, 0.20415047, 0.20080237])
